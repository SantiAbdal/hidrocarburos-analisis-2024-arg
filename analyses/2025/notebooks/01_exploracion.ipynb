# %%
import pandas as pd
from pathlib import Path
BASE = Path(__file__).parent if '__file__' in dir() else Path().resolve()

ruta_raw = BASE / "../../../data/raw/2025/produccin-de-pozos-de-gas-y-petrleo-2025.csv"
df = pd.read_csv(ruta_raw, low_memory=False)


print("=== TAMAÑO ===")
print(df.shape)

print("\n=== TIPOS DE DATOS ===")
print(df.dtypes)

print("\n=== VALORES NULOS ===")
print(df.isnull().sum())

print("\n=== ESTADÍSTICAS BÁSICAS ===")
print(df[['prod_pet', 'prod_gas', 'prod_agua', 'iny_agua', 'iny_gas', 'iny_co2']].describe())
# Out:
#         idpozo                        empresa  provincia       iny_gas
# 413326  116223  QUINTANA E&P ARGENTINA S.R.L.    Mendoza  9.267366e+06
# 412913  116279  QUINTANA E&P ARGENTINA S.R.L.    Mendoza  3.723174e+06
# 414067  157357  QUINTANA E&P ARGENTINA S.R.L.  Rio Negro  3.569000e+06
# 413317  131984  QUINTANA E&P ARGENTINA S.R.L.  Rio Negro  2.093923e+06
# 414601  131984  QUINTANA E&P ARGENTINA S.R.L.  Rio Negro  2.016000e+06
# 412083  131984  QUINTANA E&P ARGENTINA S.R.L.  Rio Negro  1.958119e+06
# 413032  157357  QUINTANA E&P ARGENTINA S.R.L.  Rio Negro  1.200586e+06
# 413853  116223  QUINTANA E&P ARGENTINA S.R.L.    Mendoza  1.081470e+06
# 413584  129375  QUINTANA E&P ARGENTINA S.R.L.    Mendoza  8.612047e+05
# 413588  130016  QUINTANA E&P ARGENTINA S.R.L.    Mendoza  8.612047e+05
