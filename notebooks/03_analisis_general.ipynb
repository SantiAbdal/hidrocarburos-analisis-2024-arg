# %%
import pandas as pd

df = pd.read_csv(
    r"C:\Users\santi\OneDrive\Escritorio\proyectos\datos_limpios.csv",
    low_memory=False
)

# 1. Producción total del año
# Por qué: la métrica más básica, el punto de partida de cualquier análisis
print("=== PRODUCCIÓN TOTAL 2024 ===")
print(f"Petróleo (m3): {df['prod_pet'].sum():,.2f}")
print(f"Gas (miles m3): {df['prod_gas'].sum():,.2f}")
print(f"Agua (m3): {df['prod_agua'].sum():,.2f}")

# 2. Producción mes a mes
# Por qué: para ver si hubo estacionalidad o caídas en algún período
print("\n=== PRODUCCIÓN MES A MES ===")
por_mes = df.groupby('mes')[['prod_pet', 'prod_gas']].sum()
print(por_mes)

# 3. Producción por provincia
# Por qué: para identificar qué provincias concentran la producción
print("\n=== PRODUCCIÓN POR PROVINCIA ===")
por_provincia = df.groupby('provincia')[['prod_pet', 'prod_gas']].sum()
por_provincia = por_provincia.sort_values('prod_pet', ascending=False)
print(por_provincia)

# 4. Top 10 empresas por producción de petróleo
# Por qué: para ver quién domina el mercado
print("\n=== TOP 10 EMPRESAS - PETRÓLEO ===")
por_empresa = df.groupby('empresa')[['prod_pet', 'prod_gas']].sum()
por_empresa = por_empresa.sort_values('prod_pet', ascending=False)
print(por_empresa.head(10))

# 5. Convencional vs No Convencional
# Por qué: contexto clave del mercado argentino actual
print("\n=== CONVENCIONAL VS NO CONVENCIONAL ===")
por_recurso = df.groupby('tipo_de_recurso')[['prod_pet', 'prod_gas']].sum()
por_recurso['pct_pet'] = (por_recurso['prod_pet'] / por_recurso['prod_pet'].sum() * 100).round(2)
por_recurso['pct_gas'] = (por_recurso['prod_gas'] / por_recurso['prod_gas'].sum() * 100).round(2)
print(por_recurso)

# 6. Concentración de mercado
# Por qué: saber cuántas empresas concentran el 80% de la producción
print("\n=== CONCENTRACIÓN DE MERCADO ===")
por_empresa_sorted = por_empresa.sort_values('prod_pet', ascending=False)
por_empresa_sorted['pct_acumulado'] = (
    por_empresa_sorted['prod_pet'].cumsum() / 
    por_empresa_sorted['prod_pet'].sum() * 100
)
empresas_80 = por_empresa_sorted[por_empresa_sorted['pct_acumulado'] <= 80]
print(f"Empresas que concentran el 80% de producción de petróleo: {len(empresas_80)}")
print(empresas_80[['prod_pet', 'pct_acumulado']])
# Out:
# === PRODUCCIÓN TOTAL 2024 ===
# Petróleo (m3): 41,144,532.07
# Gas (miles m3): 50,718,402.25
# Agua (m3): 340,965,820.77
#
# === PRODUCCIÓN MES A MES ===
#          prod_pet      prod_gas
# mes
# 1    3.349597e+06  3.837767e+06
# 2    3.137697e+06  3.887534e+06
# 3    3.393408e+06  4.174236e+06
# 4    3.297381e+06  4.084633e+06
# 5    3.416159e+06  4.654304e+06
# 6    3.196899e+06  4.426175e+06
# 7    3.374949e+06  4.709010e+06
# 8    3.544882e+06  4.743925e+06
# 9    3.376837e+06  4.400334e+06
# 10   3.664219e+06  4.127371e+06
# 11   3.619164e+06  3.814647e+06
# 12   3.773340e+06  3.858467e+06
#
# === PRODUCCIÓN POR PROVINCIA ===
#                       prod_pet      prod_gas
# provincia
# Neuquén           2.405963e+07  3.476237e+07
# Chubut            7.429914e+06  2.568032e+06
# Santa Cruz        3.858864e+06  3.221921e+06
# Mendoza           3.270107e+06  5.536920e+05
# Rio Negro         1.175821e+06  1.191088e+06
# La Pampa          7.346640e+05  2.160776e+05
# Tierra del Fuego  2.124103e+05  1.513776e+06
# Estado Nacional   1.944207e+05  5.454655e+06
# Salta             1.637037e+05  1.228863e+06
# Formosa           3.512098e+04  5.144100e+03
# Jujuy             9.881062e+03  2.786540e+03
#
# === TOP 10 EMPRESAS - PETRÓLEO ===
#                                          prod_pet      prod_gas
# empresa
# YPF S.A.                             2.008161e+07  1.230856e+07
# PAN AMERICAN ENERGY SL               6.100918e+06  6.773467e+06
# VISTA ENERGY ARGENTINA SAU           3.516340e+06  4.352788e+05
# PLUSPETROL S.A.                      2.045330e+06  3.007003e+06
# SHELL ARGENTINA S.A.                 1.759558e+06  1.783444e+05
# TECPETROL S.A.                       1.138461e+06  6.810832e+06
# CGC ENERGIA SAU                      1.067260e+06  7.150936e+05
# KILWER S.A.                          6.565709e+05  4.680657e+04
# COMPAÑÍAS ASOCIADAS PETROLERAS S.A.  6.209819e+05  3.186741e+04
# CAPEX S.A.                           5.693341e+05  6.113048e+05
#
# === CONVENCIONAL VS NO CONVENCIONAL ===
#                      prod_pet      prod_gas  pct_pet  pct_gas
# tipo_de_recurso
# CONVENCIONAL     1.829094e+07  1.875612e+07    44.46    36.98
# NO CONVENCIONAL  2.284931e+07  3.195417e+07    55.53    63.00
# NO DISCRIMINADO  4.277625e+03  1.403854e+02     0.01     0.00
# SIN RESERVORIO   0.000000e+00  7.972724e+03     0.00     0.02
#
# === CONCENTRACIÓN DE MERCADO ===
# Empresas que concentran el 80% de producción de petróleo: 4
#                                 prod_pet  pct_acumulado
# empresa
# YPF S.A.                    2.008161e+07      48.807478
# PAN AMERICAN ENERGY SL      6.100918e+06      63.635495
# VISTA ENERGY ARGENTINA SAU  3.516340e+06      72.181808
# PLUSPETROL S.A.             2.045330e+06      77.152893
